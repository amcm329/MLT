# %%
#Getting al basic functions.
import operator
import Utilities.Utilities as uti
print(dir(uti))
#Splitting data into lists.
lista_0,lista_1,lista_2,lista_3,lista_4,lista_5,lista_6 = uti.split_data()

#Calculating each list's frequencies.
dict_0 = uti.get_frequencies(lista_0)
dict_1 = uti.get_frequencies(lista_1)
dict_2 = uti.get_frequencies(lista_2)
dict_3 = uti.get_frequencies(lista_3)
dict_4 = uti.get_frequencies(lista_4)
dict_5 = uti.get_frequencies(lista_5)
dict_6 = uti.get_frequencies(lista_6)

#Converting each dictionary into a list again but thist time sorting
#each element accordin to it's frequency. 
result_0 = sorted(dict_0.items(), key=operator.itemgetter(1))
result_1 = sorted(dict_1.items(), key=operator.itemgetter(1))
result_2 = sorted(dict_2.items(), key=operator.itemgetter(1))
result_3 = sorted(dict_3.items(), key=operator.itemgetter(1))
result_4 = sorted(dict_4.items(), key=operator.itemgetter(1))
result_5 = sorted(dict_5.items(), key=operator.itemgetter(1))
result_6 = sorted(dict_6.items(), key=operator.itemgetter(1))

#Getting difference of patterns.
pattern_0 = uti.find_patterns(lista_0,result_0)
pattern_1 = uti.find_patterns(lista_1,result_1)
pattern_2 = uti.find_patterns(lista_2,result_2)
pattern_3 = uti.find_patterns(lista_3,result_3)
pattern_4 = uti.find_patterns(lista_4,result_4)
pattern_5 = uti.find_patterns(lista_5,result_5)
pattern_6 = uti.find_patterns(lista_6,result_6)

#Getting difference of frequencies.
frequencies_of_differences_0 = uti.get_frequencies_of_differences(lista_0)
frequencies_of_differences_1 = uti.get_frequencies_of_differences(lista_1)
frequencies_of_differences_2 = uti.get_frequencies_of_differences(lista_2)
frequencies_of_differences_3 = uti.get_frequencies_of_differences(lista_3)
frequencies_of_differences_4 = uti.get_frequencies_of_differences(lista_4)
frequencies_of_differences_5 = uti.get_frequencies_of_differences(lista_5)
frequencies_of_differences_6 = uti.get_frequencies_of_differences(lista_6)

print(" PRIMER NUMERO: ")
uti.print_elements(pattern_0,frequencies_of_differences_0)
print("--------------------------------")

print(" SEGUNDO NUMERO: ")
uti.print_elements(pattern_1,frequencies_of_differences_1)
print("--------------------------------")

print(" TERCER NUMERO: ")
uti.print_elements(pattern_2,frequencies_of_differences_2)
print("--------------------------------")

print(" CUARTO NUMERO: ")
uti.print_elements(pattern_3,frequencies_of_differences_3)
print("--------------------------------")

print("QUINTO NUMERO: ")
uti.print_elements(pattern_4,frequencies_of_differences_4)
print("--------------------------------")

print("SEXTO NUMERO")
uti.print_elements(pattern_5,frequencies_of_differences_5)
print("--------------------------------")

print("NUMERO ADICIONAL")
uti.print_elements(pattern_6,frequencies_of_differences_6)
print("--------------------------------")
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'deja_vu', 'find_patterns', 'get_frequencies', 'get_frequencies_of_differences', 'operator', 'print_elements', 'split_data']
#  PRIMER NUMERO:
# Ordered Frequencies: [(32, 1), (-28, 1), (-27, 1), (-36, 1), (28, 1), (-39, 1), (34, 1), (-26, 2), (27, 2), (33, 2), (-25, 3), (-29, 3), (-32, 3), (23, 4), (-24, 4), (-23, 4), (19, 5), (-22, 5), (-21, 5), (24, 5), (26, 5), (-20, 6), (20, 7), (22, 9), (-18, 11), (21, 12), (18, 14), (-17, 15), (-19, 17), (17, 17), (16, 20), (-15, 20), (-16, 20), (15, 24), (13, 24), (14, 32), (-14, 34), (-13, 37), (12, 40), (11, 43), (-12, 44), (-11, 49), (-10, 54), (10, 54), (-9, 59), (9, 75), (7, 83), (-8, 87), (8, 91), (-6, 93), (-7, 94), (6, 118), (5, 124), (-5, 126), (4, 156), (-4, 156), (3, 161), (-3, 161), (2, 186), (1, 192), (-2, 194), (-1, 203), (0, 244)]
# Numbers w. Differences in Order: [['4', '5', '28', 23, 4], ['7', '5', '29', 24, 5], ['4', '5', '27', 22, 9], ['17', '5', '26', 21, 12], ['1', '5', '23', 18, 14], ['3', '5', '22', 17, 17], ['5', '5', '21', 16, 20], ['2', '5', '20', 15, 24], ['2', '5', '18', 13, 24], ['16', '5', '19', 14, 32], ['2', '5', '17', 12, 40], ['1', '5', '16', 11, 43], ['18', '5', '15', 10, 54], ['6', '5', '14', 9, 75], ['11', '5', '12', 7, 83], ['3', '5', '13', 8, 91], ['7', '5', '11', 6, 118], ['11', '5', '10', 5, 124], ['5', '5', '9', 4, 156], ['3', '5', '1', -4, 156], ['2', '5', '2', -3, 161], ['4', '5', '8', 3, 161], ['1', '5', '7', 2, 186], ['4', '5', '6', 1, 192], ['6', '5', '3', -2, 194], ['1', '5', '4', -1, 203], ['7', '5', '5', 0, 244]]
# Numbers: ['28', '29', '27', '26', '23', '22', '21', '20', '18', '19', '17', '16', '15', '14', '12', '13', '11', '10', '9', '1', '2', '8', '7', '6', '3', '4', '5']
# --------------------------------
#  SEGUNDO NUMERO:
# Ordered Frequencies: [(-29, 1), (32, 1), (30, 1), (-35, 1), (40, 1), (-38, 1), (-36, 1), (31, 1), (38, 1), (27, 2), (-30, 2), (34, 2), (33, 2), (-34, 2), (28, 3), (-28, 3), (25, 3), (29, 3), (-31, 4), (-26, 4), (23, 7), (-23, 7), (24, 7), (26, 8), (-25, 9), (-24, 10), (-27, 10), (-22, 13), (-21, 13), (-20, 15), (-19, 16), (20, 16), (22, 16), (21, 22), (19, 24), (-18, 25), (-17, 27), (16, 27), (17, 28), (18, 28), (15, 35), (-15, 36), (14, 39), (-16, 40), (-14, 46), (-11, 53), (13, 55), (-13, 56), (12, 63), (-12, 63), (11, 70), (10, 76), (-10, 78), (-9, 86), (9, 87), (-7, 88), (-8, 94), (8, 100), (5, 100), (6, 103), (-6, 109), (3, 115), (4, 115), (7, 117), (-4, 124), (-5, 125), (-3, 126), (-1, 127), (1, 130), (2, 138), (0, 151), (-2, 153)]
# Numbers w. Differences in Order: [['21', '6', '35', 29, 3], ['11', '6', '30', 24, 7], ['8', '6', '32', 26, 8], ['19', '6', '28', 22, 16], ['3', '6', '26', 20, 16], ['11', '6', '27', 21, 22], ['12', '6', '25', 19, 24], ['25', '6', '22', 16, 27], ['7', '6', '23', 17, 28], ['14', '6', '24', 18, 28], ['20', '6', '21', 15, 35], ['3', '6', '20', 14, 39], ['18', '6', '19', 13, 55], ['4', '6', '18', 12, 63], ['9', '6', '17', 11, 70], ['12', '6', '16', 10, 76], ['10', '6', '15', 9, 87], ['19', '6', '14', 8, 100], ['16', '6', '11', 5, 100], ['4', '6', '12', 6, 103], ['15', '6', '9', 3, 115], ['7', '6', '10', 4, 115], ['16', '6', '13', 7, 117], ['8', '6', '2', -4, 124], ['12', '6', '3', -3, 126], ['13', '6', '5', -1, 127], ['8', '6', '7', 1, 130], ['25', '6', '8', 2, 138], ['11', '6', '6', 0, 151], ['6', '6', '4', -2, 153]]
# Numbers: ['35', '30', '32', '28', '26', '27', '25', '22', '23', '24', '21', '20', '19', '18', '17', '16', '15', '14', '11', '12', '9', '10', '13', '2', '3', '5', '7', '8', '6', '4']
# --------------------------------
#  TERCER NUMERO:
# Ordered Frequencies: [(40, 1), (-35, 1), (36, 1), (30, 1), (38, 1), (-38, 1), (-34, 2), (-42, 2), (-33, 2), (31, 2), (34, 3), (29, 3), (-29, 3), (-36, 3), (35, 3), (-30, 4), (-28, 4), (-27, 5), (27, 5), (32, 5), (-31, 5), (-32, 6), (-25, 7), (28, 8), (-26, 10), (-21, 11), (26, 11), (23, 12), (24, 12), (25, 12), (-24, 12), (-23, 14), (21, 22), (-22, 23), (-20, 24), (20, 26), (-19, 27), (19, 27), (22, 29), (-17, 32), (17, 33), (-18, 33), (18, 35), (15, 37), (16, 38), (-16, 43), (-15, 48), (-12, 58), (14, 59), (13, 59), (-14, 63), (-13, 64), (12, 66), (11, 68), (-11, 70), (8, 74), (-10, 75), (10, 76), (9, 80), (-7, 84), (5, 86), (-9, 86), (-5, 89), (-6, 92), (0, 98), (-3, 102), (4, 107), (-8, 109), (7, 109), (3, 111), (2, 112), (-1, 115), (6, 118), (-2, 126), (-4, 129), (1, 131)]
# Numbers w. Differences in Order: [['34', '14', '43', 29, 3], ['21', '14', '46', 32, 5], ['32', '14', '42', 28, 8], ['22', '14', '40', 26, 11], ['8', '14', '39', 25, 12], ['45', '14', '37', 23, 12], ['24', '14', '35', 21, 22], ['20', '14', '34', 20, 26], ['31', '14', '33', 19, 27], ['17', '14', '36', 22, 29], ['22', '14', '31', 17, 33], ['14', '14', '32', 18, 35], ['21', '14', '29', 15, 37], ['20', '14', '30', 16, 38], ['25', '14', '27', 13, 59], ['9', '14', '28', 14, 59], ['8', '14', '26', 12, 66], ['23', '14', '25', 11, 68], ['10', '14', '22', 8, 74], ['24', '14', '24', 10, 76], ['7', '14', '23', 9, 80], ['21', '14', '5', -9, 86], ['18', '14', '19', 5, 86], ['13', '14', '9', -5, 89], ['34', '14', '8', -6, 92], ['16', '14', '14', 0, 98], ['8', '14', '11', -3, 102], ['3', '14', '18', 4, 107], ['11', '14', '21', 7, 109], ['14', '14', '6', -8, 109], ['16', '14', '17', 3, 111], ['23', '14', '16', 2, 112], ['15', '14', '13', -1, 115], ['28', '14', '20', 6, 118], ['18', '14', '12', -2, 126], ['22', '14', '10', -4, 129], ['31', '14', '15', 1, 131]]
# Numbers: ['43', '46', '42', '40', '39', '37', '35', '34', '33', '36', '31', '32', '29', '30', '27', '28', '26', '25', '22', '24', '23', '5', '19', '9', '8', '14', '11', '18', '21', '6', '17', '16', '13', '20', '12', '10', '15']
# --------------------------------
#  CUARTO NUMERO:
# Ordered Frequencies: [(30, 1), (-36, 1), (-40, 1), (32, 1), (36, 1), (-34, 1), (38, 1), (34, 2), (-33, 2), (-35, 2), (-32, 3), (-29, 3), (-31, 4), (29, 5), (-24, 6), (-27, 6), (25, 6), (-30, 6), (-28, 7), (31, 7), (24, 8), (-26, 10), (28, 10), (-25, 11), (-23, 11), (26, 11), (-22, 15), (27, 16), (21, 18), (20, 19), (23, 19), (19, 21), (22, 22), (-20, 24), (18, 25), (-18, 26), (17, 28), (-21, 28), (-19, 29), (-15, 34), (16, 37), (-17, 39), (-16, 46), (15, 52), (-14, 54), (14, 57), (12, 63), (11, 63), (-13, 64), (-11, 66), (13, 69), (-12, 70), (-10, 74), (8, 74), (10, 79), (-7, 81), (-9, 82), (9, 89), (6, 91), (-8, 95), (4, 101), (7, 102), (-3, 103), (-5, 108), (-1, 109), (-6, 109), (-4, 113), (-2, 116), (0, 119), (5, 119), (1, 120), (2, 122), (3, 128)]
# Numbers w. Differences in Order: [['54', '23', '52', 29, 5], ['46', '23', '47', 24, 8], ['36', '23', '49', 26, 11], ['50', '23', '50', 27, 16], ['34', '23', '46', 23, 19], ['32', '23', '42', 19, 21], ['16', '23', '45', 22, 22], ['25', '23', '8', -15, 34], ['35', '23', '38', 15, 52], ['20', '23', '37', 14, 57], ['17', '23', '34', 11, 63], ['21', '23', '10', -13, 64], ['23', '23', '36', 13, 69], ['14', '23', '11', -12, 70], ['11', '23', '13', -10, 74], ['32', '23', '31', 8, 74], ['33', '23', '33', 10, 79], ['21', '23', '16', -7, 81], ['29', '23', '14', -9, 82], ['26', '23', '32', 9, 89], ['20', '23', '29', 6, 91], ['23', '23', '15', -8, 95], ['27', '23', '27', 4, 101], ['22', '23', '30', 7, 102], ['22', '23', '20', -3, 103], ['20', '23', '18', -5, 108], ['32', '23', '22', -1, 109], ['30', '23', '17', -6, 109], ['24', '23', '19', -4, 113], ['18', '23', '21', -2, 116], ['30', '23', '23', 0, 119], ['22', '23', '28', 5, 119], ['16', '23', '24', 1, 120], ['17', '23', '25', 2, 122], ['27', '23', '26', 3, 128]]
# Numbers: ['52', '47', '49', '50', '46', '42', '45', '8', '38', '37', '34', '10', '36', '11', '13', '31', '33', '16', '14', '32', '29', '15', '27', '30', '20', '18', '22', '17', '19', '21', '23', '28', '24', '25', '26']
# --------------------------------
# QUINTO NUMERO:
# Ordered Frequencies: [(33, 1), (31, 1), (-31, 1), (-39, 1), (34, 1), (-30, 1), (-35, 1), (35, 1), (29, 2), (-33, 2), (-29, 2), (-28, 4), (-27, 5), (28, 5), (-25, 5), (-24, 6), (26, 7), (27, 7), (-23, 8), (-26, 8), (25, 10), (20, 11), (21, 11), (23, 11), (24, 12), (-20, 13), (-21, 16), (22, 19), (18, 20), (-22, 20), (-18, 22), (19, 25), (-19, 26), (17, 28), (-17, 29), (-15, 36), (16, 39), (-16, 43), (15, 44), (-14, 46), (-13, 48), (14, 48), (-11, 53), (13, 61), (10, 63), (9, 67), (-12, 68), (11, 74), (12, 77), (8, 77), (-9, 83), (-10, 84), (-8, 93), (-7, 96), (4, 101), (-6, 103), (6, 104), (5, 105), (7, 111), (2, 116), (-5, 119), (-2, 123), (3, 128), (-3, 134), (1, 135), (-1, 136), (-4, 147), (0, 161)]
# Numbers w. Differences in Order: [['41', '40', '17', -23, 8], ['24', '40', '19', -21, 16], ['30', '40', '18', -22, 20], ['37', '40', '22', -18, 22], ['36', '40', '21', -19, 26], ['17', '40', '23', -17, 29], ['46', '40', '25', -15, 36], ['40', '40', '24', -16, 43], ['22', '40', '26', -14, 46], ['29', '40', '27', -13, 48], ['43', '40', '54', 14, 48], ['26', '40', '29', -11, 53], ['49', '40', '53', 13, 61], ['42', '40', '50', 10, 63], ['37', '40', '49', 9, 67], ['33', '40', '28', -12, 68], ['46', '40', '51', 11, 74], ['27', '40', '48', 8, 77], ['48', '40', '52', 12, 77], ['27', '40', '31', -9, 83], ['40', '40', '30', -10, 84], ['38', '40', '32', -8, 93], ['28', '40', '33', -7, 96], ['49', '40', '44', 4, 101], ['33', '40', '34', -6, 103], ['30', '40', '46', 6, 104], ['50', '40', '45', 5, 105], ['51', '40', '47', 7, 111], ['25', '40', '42', 2, 116], ['43', '40', '35', -5, 119], ['32', '40', '38', -2, 123], ['31', '40', '43', 3, 128], ['41', '40', '37', -3, 134], ['24', '40', '41', 1, 135], ['34', '40', '39', -1, 136], ['26', '40', '36', -4, 147], ['29', '40', '40', 0, 161]]
# Numbers: ['17', '19', '18', '22', '21', '23', '25', '24', '26', '27', '54', '29', '53', '50', '49', '28', '51', '48', '52', '31', '30', '32', '33', '44', '34', '46', '45', '47', '42', '35', '38', '43', '37', '41', '39', '36', '40']
# --------------------------------
# SEXTO NUMERO
# Ordered Frequencies: [(-29, 1), (36, 1), (-26, 1), (-33, 1), (-31, 2), (29, 2), (-28, 2), (-24, 3), (-27, 3), (26, 3), (25, 3), (27, 4), (-22, 4), (23, 5), (-25, 5), (24, 5), (21, 5), (-21, 6), (-19, 7), (22, 8), (19, 9), (20, 10), (16, 14), (18, 14), (-18, 16), (-16, 18), (-20, 18), (-14, 21), (-17, 21), (17, 22), (15, 27), (-15, 28), (13, 33), (-13, 33), (-12, 35), (14, 35), (12, 41), (11, 53), (-10, 54), (-11, 54), (10, 55), (9, 61), (-9, 65), (8, 67), (-7, 86), (-8, 86), (7, 89), (6, 95), (-6, 99), (5, 119), (-5, 120), (-4, 147), (4, 150), (-3, 171), (2, 175), (3, 179), (-2, 202), (-1, 210), (1, 219), (0, 243)]
# Numbers w. Differences in Order: [['55', '45', '20', -25, 5], ['52', '45', '30', -15, 28], ['33', '45', '33', -12, 35], ['53', '45', '56', 11, 53], ['16', '45', '34', -11, 54], ['44', '45', '35', -10, 54], ['22', '45', '55', 10, 55], ['47', '45', '54', 9, 61], ['38', '45', '36', -9, 65], ['54', '45', '53', 8, 67], ['34', '45', '37', -8, 86], ['45', '45', '52', 7, 89], ['48', '45', '51', 6, 95], ['41', '45', '50', 5, 119], ['46', '45', '40', -5, 120], ['47', '45', '41', -4, 147], ['49', '45', '49', 4, 150], ['36', '45', '42', -3, 171], ['33', '45', '47', 2, 175], ['35', '45', '48', 3, 179], ['45', '45', '43', -2, 202], ['33', '45', '44', -1, 210], ['46', '45', '46', 1, 219], ['47', '45', '45', 0, 243]]
# Numbers: ['20', '30', '33', '56', '34', '35', '55', '54', '36', '53', '37', '52', '51', '50', '40', '41', '49', '42', '47', '48', '43', '44', '46', '45']
# --------------------------------
# NUMERO ADICIONAL
# Ordered Frequencies: [(-50, 1), (-53, 1), (54, 1), (50, 2), (47, 2), (52, 2), (45, 2), (-49, 2), (49, 3), (-47, 4), (-48, 4), (-45, 5), (41, 5), (48, 5), (-46, 5), (44, 6), (43, 6), (-44, 8), (-38, 9), (-43, 9), (-42, 9), (39, 10), (42, 10), (46, 10), (37, 11), (38, 11), (35, 12), (-36, 13), (-41, 13), (40, 14), (-39, 14), (31, 14), (-37, 16), (-33, 16), (-35, 16), (-40, 16), (-34, 18), (32, 19), (33, 20), (36, 22), (-28, 22), (34, 24), (-29, 25), (-30, 25), (22, 25), (27, 26), (-31, 26), (30, 28), (-32, 28), (28, 28), (-23, 29), (-19, 30), (-25, 31), (29, 31), (26, 32), (-22, 33), (24, 33), (-20, 34), (-16, 34), (-27, 35), (17, 38), (-26, 39), (-21, 39), (9, 39), (25, 40), (21, 40), (16, 41), (-18, 42), (-24, 42), (-12, 43), (20, 43), (23, 43), (-10, 44), (-15, 44), (6, 44), (19, 44), (13, 44), (11, 45), (-17, 47), (18, 47), (15, 48), (14, 50), (-11, 51), (-14, 52), (-13, 53), (12, 53), (-9, 57), (-4, 59), (8, 59), (-2, 59), (-8, 60), (-1, 61), (-6, 61), (-3, 61), (7, 62), (-7, 62), (10, 63), (2, 67), (3, 70), (-5, 71), (0, 71), (1, 71), (4, 73), (5, 78)]
# Numbers w. Differences in Order: [['39', '10', '51', 41, 5], ['26', '10', '54', 44, 6], ['5', '10', '56', 46, 10], ['29', '10', '45', 35, 12], ['52', '10', '41', 31, 14], ['53', '10', '42', 32, 19], ['31', '10', '43', 33, 20], ['9', '10', '46', 36, 22], ['37', '10', '44', 34, 24], ['6', '10', '32', 22, 25], ['5', '10', '38', 28, 28], ['43', '10', '40', 30, 28], ['8', '10', '39', 29, 31], ['19', '10', '36', 26, 32], ['11', '10', '27', 17, 38], ['29', '10', '31', 21, 40], ['43', '10', '35', 25, 40], ['31', '10', '26', 16, 41], ['37', '10', '30', 20, 43], ['13', '10', '33', 23, 43], ['20', '10', '29', 19, 44], ['44', '10', '16', 6, 44], ['6', '10', '21', 11, 45], ['26', '10', '28', 18, 47], ['5', '10', '25', 15, 48], ['3', '10', '22', 12, 53], ['13', '10', '1', -9, 57], ['52', '10', '6', -4, 59], ['38', '10', '8', -2, 59], ['16', '10', '2', -8, 60], ['39', '10', '7', -3, 61], ['18', '10', '4', -6, 61], ['27', '10', '3', -7, 62], ['33', '10', '17', 7, 62], ['9', '10', '20', 10, 63], ['27', '10', '12', 2, 67], ['19', '10', '13', 3, 70], ['32', '10', '5', -5, 71], ['7', '10', '11', 1, 71], ['32', '10', '10', 0, 71], ['9', '10', '14', 4, 73]]
# Numbers: ['51', '54', '56', '45', '41', '42', '43', '46', '44', '32', '38', '40', '39', '36', '27', '31', '35', '26', '30', '33', '29', '16', '21', '28', '25', '22', '1', '6', '8', '2', '7', '4', '3', '17', '20', '12', '13', '5', '11', '10', '14']
# --------------------------------

# %%
#nuevo metodo
import sys

def metodo_busqueda(numero,lista):
    resultado = -1
    for x in range(len(lista)):
        elemento = lista[x]
        if numero == elemento:
           resultado = x
        
    return resultado

file_handler = open("Melate.csv")
lines = file_handler.readlines()[1:]
longitud = len(lines)
file_handler.close()

actual = 2000

final_0 = []
final_1 = []
final_2 = []
final_3 = []
final_4 = []
final_5 = []
final_6 = []

for x in range (actual,longitud):
    file_handler = open("Melate.csv")
    lines = file_handler.readlines()[1:x]
    file_handler.close()

    prediction = lines[-1][:-1].split(",")[2:9]
    del lines[-1]
    
    numero_0 = prediction[0]
    numero_1 = prediction[1]
    numero_2 = prediction[2]
    numero_3 = prediction[3]
    numero_4 = prediction[4]
    numero_5 = prediction[5]
    numero_6 = prediction[6]
    
    #print("ss",prediction,"sss")
    #sys.exit()
    lista_0 = []
    lista_1 = []
    lista_2 = []
    lista_3 = []
    lista_4 = []
    lista_5 = []
    lista_6 = []

    for line in lines:
        if line != "\n":
           splitted_line = line.split(",")
           lista_0.insert(0,splitted_line[2])
           lista_1.insert(0,splitted_line[3])
           lista_2.insert(0,splitted_line[4])
           lista_3.insert(0,splitted_line[5])
           lista_4.insert(0,splitted_line[6])
           lista_5.insert(0,splitted_line[7])
           lista_6.insert(0,splitted_line[8])

    dict_0 = frequencies(lista_0)
    dict_1 = frequencies(lista_1)
    dict_2 = frequencies(lista_2)
    dict_3 = frequencies(lista_3)
    dict_4 = frequencies(lista_4)
    dict_5 = frequencies(lista_5)
    dict_6 = frequencies(lista_6)


    result_0 = sorted(dict_0.items(), key=operator.itemgetter(1))
    result_1 = sorted(dict_1.items(), key=operator.itemgetter(1))
    result_2 = sorted(dict_2.items(), key=operator.itemgetter(1))
    result_3 = sorted(dict_3.items(), key=operator.itemgetter(1))
    result_4 = sorted(dict_4.items(), key=operator.itemgetter(1))
    result_5 = sorted(dict_5.items(), key=operator.itemgetter(1))
    result_6 = sorted(dict_6.items(), key=operator.itemgetter(1))


    final_0.append(metodo_busqueda(numero_0,print_elements(find_patterns(lista_0,result_0),frequencies_of_differences(lista_0))))
    final_1.append(metodo_busqueda(numero_1,print_elements(find_patterns(lista_1,result_1),frequencies_of_differences(lista_1))))
    final_2.append(metodo_busqueda(numero_2,print_elements(find_patterns(lista_2,result_2),frequencies_of_differences(lista_2))))
    final_3.append(metodo_busqueda(numero_3,print_elements(find_patterns(lista_3,result_3),frequencies_of_differences(lista_3))))
    final_4.append(metodo_busqueda(numero_4,print_elements(find_patterns(lista_4,result_4),frequencies_of_differences(lista_4))))
    final_5.append(metodo_busqueda(numero_5,print_elements(find_patterns(lista_5,result_5),frequencies_of_differences(lista_5))))
    final_6.append(metodo_busqueda(numero_6,print_elements(find_patterns(lista_6,result_6),frequencies_of_differences(lista_6))))      
    
    
print(final_0[-10:-1])
print(final_1[-10:-1])
print(final_2[-10:-1])
print(final_3[-10:-1])
print(final_4[-10:-1])
print(final_5[-10:-1])
print(final_6[-10:-1])

# %%
print(final_0[-30:-1])
print(final_1[-30:-1])
print(final_2[-30:-1])
print(final_3[-30:-1])
print(final_4[-30:-1])
print(final_5[-30:-1])
print(final_6[-30:-1])

# %%
import matplotlib.pyplot as plt
plt.plot(list(range(49)),final_0[-50:-1])
